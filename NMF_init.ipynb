# %%
import pandas as pd
import numpy as np

#import pca
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('X_duplet.csv')
X = df.values

# %%
pca = PCA(n_components=3)
pca.fit(X.T)
Xpc = pca.transform(X.T)

# %%
def softplus(x):
    return np.log(1 + np.exp(x))

# %%
plt.plot(Xpc)
plt.show()

plt.plot(np.array(df).T)
plt.show()
